# %% [markdown]
# # Decision Tree Classifier (ID3 Algorithm)

# %% [markdown]
# **Reading the Dataset**

# %%
import pandas as pd

dataframe = pd.read_csv('car.data.txt',header = None, names = ['Buying','Maintenance','Doors','Persons','Lugboot','Safety','Class'])
dataframe.head()
# Out:
#   Buying Maintenance Doors Persons Lugboot Safety  Class
# 0  vhigh       vhigh     2       2   small    low  unacc
# 1  vhigh       vhigh     2       2   small    med  unacc
# 2  vhigh       vhigh     2       2   small   high  unacc
# 3  vhigh       vhigh     2       2     med    low  unacc
# 4  vhigh       vhigh     2       2     med    med  unacc

# %% [markdown]
# **Functions to Calculate Entropy and Information Gain**

# %%
import numpy as np

def entropy(df,label):
    values,counts = np.unique(df[label],return_counts=True)
    return sum((-counts[i]/np.sum(counts))*np.log2(counts[i]/np.sum(counts)) for i in range(len(counts)))

def information_gain(df,feature,label):
    e = entropy(df,label)
    values,counts = np.unique(df[feature],return_counts=True)
    return e-sum((counts[i]/sum(counts))*entropy(df.where(df[feature]==values[i]).dropna(),label) for i in range(len(counts)))

# %% [markdown]
# **Function to Create Decision Tree**

# %%
def decision_tree(dataset,features,label,parent=None):
    dat = np.unique(dataset[label],return_counts=True)
    unq = np.unique(dataset[label])
    if len(unq)==1:        #If there's only one value in the target label then return that value
        return unq[0]
    elif len(dataset) == 0:
        return unq[np.argmax(dat[1])]
    elif len(features) == 0: #If the feature set becomes empty i.e. all the features have been utilised
        return parent
    else:
        parent = unq[np.argmax(dat[1])]
        IG = [information_gain(dataset,feature,label) for feature in features]
        split_feature = features[np.argmax(IG)]
        DT = {'Split Feature':split_feature}
        for value in np.unique(dataset[split_feature]):
            new_features = [i for i in features if i != split_feature]
            new_dataset = dataset.where(dataset[split_feature]==value).dropna()
            new_tree = decision_tree(new_dataset,new_features,label,parent)
            DT[value] = new_tree
    return DT

# %% [markdown]
# **Function to Make Prediction**

# %%
import random

def predict(X_test,tree):
    layer = tree
    while type(layer) == dict:
        a = layer['Split Feature']
        b = X_test[a]
        if b in layer:
            layer = layer[b]
        else:
            p = layer.items()
            p = [m[1] for m in p if m[0] != 'Split Feature']
            layer = random.choice(p)
    return layer

# %% [markdown]
# **Function to Generate Decision Rules**

# %%
def gen_rules(decisiontree,rules,lst = [],split_feature = None):
    split_feature = decisiontree['Split Feature']
    for x in decisiontree:
        new_list = list(lst)
        if x!= 'Split Feature':
            if type(decisiontree[x]) == dict:
                new_list.append((split_feature, x))
                gen_rules(decisiontree[x],rules,new_list,split_feature)
            else:
                new_list.append((split_feature,x))
                if decisiontree[x] not in rules:
                    rules[decisiontree[x]] = set()
                rules[decisiontree[x]].add(tuple(new_list))

# %% [markdown]
# **Function to print Decision Rules**

# %%
def print_decisionRules(rules):
    for y in rules:
        j = 0
        for x in rules[y]:
            print('(',end='')
            for i in range(len(x)):
                print(f'{x[i][0]} = {x[i][1]}',end='')
                if i < len(x)-1:
                    print(' ∧ ',end='')
            if j < len(rules[y])-1:
                print(') ∨ ',end='')
            else:
                print(')',end='')
            j = j+1
        print(f' => {y}\n')

# %% [markdown]
# **Split the Dataset into Training and Testing Data**

# %%
from sklearn.model_selection import train_test_split

X_train,X_test = train_test_split(dataframe,test_size=0.2) #80% Training Data and 20% Testing Data

# %% [markdown]
# **Create the Decision Tree (ID3 Tree)**

# %%
features = list(dataframe.columns)
features.remove('Class')
decisiontree = decision_tree(X_train,features,'Class')

# %% [markdown]
# **Generate Decision Rules**

# %%
rules = {}
gen_rules(decisiontree,rules)

# %% [markdown]
# **Export the Tree to File**

# %%
import sys,json

current_stdout = sys.stdout
with open('Output_Tree.txt','w') as tree:
    sys.stdout = tree
    print(json.dumps(decisiontree,indent = 4))
    sys.stdout = current_stdout

# %% [markdown]
# ***TREE***

# %%
print("GENERATED DECISION TREE\n\nA tree node has split feature which is its name and then sub trees for different values of that feature\n")
print(json.dumps(decisiontree,indent = 4))
# Out:
# GENERATED DECISION TREE
#
# A tree node has split feature which is its name and then sub trees for different values of that feature
#
# {
#     "Split Feature": "Safety",
#     "high": {
#         "Split Feature": "Persons",
#         "2": "unacc",
#         "4": {
#             "Split Feature": "Buying",
#             "high": {
#                 "Split Feature": "Maintenance",
#                 "high": "acc",
#                 "low": "acc",
#                 "med": "acc",
#                 "vhigh": "unacc"
#             },
#             "low": {
#                 "Split Feature": "Maintenance",
#                 "high": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "acc",
#                         "4": "vgood",
#                         "5more": "vgood"
#                     },
#                     "small": "acc"
#                 },
#                 "low": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "good",
#                         "3": "good",
#                         "4": "vgood",
#                         "5more": "vgood"
#                     },
#                     "small": "good"
#                 },
#                 "med": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": "vgood",
#                     "small": "good"
#                 },
#                 "vhigh": "acc"
#             },
#             "med": {
#                 "Split Feature": "Maintenance",
#                 "high": "acc",
#                 "low": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "good",
#                         "3": "good",
#                         "4": "vgood",
#                         "5more": "vgood"
#                     },
#                     "small": "good"
#                 },
#                 "med": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "3": "acc",
#                         "5more": "vgood"
#                     },
#                     "small": "acc"
#                 },
#                 "vhigh": "acc"
#             },
#             "vhigh": {
#                 "Split Feature": "Maintenance",
#                 "high": "unacc",
#                 "low": "acc",
#                 "med": "acc",
#                 "vhigh": "unacc"
#             }
#         },
#         "more": {
#             "Split Feature": "Buying",
#             "high": {
#                 "Split Feature": "Maintenance",
#                 "high": {
#                     "Split Feature": "Doors",
#                     "2": {
#                         "Split Feature": "Lugboot",
#                         "big": "acc",
#                         "med": "acc",
#                         "small": "unacc"
#                     },
#                     "3": "acc",
#                     "4": "acc",
#                     "5more": "acc"
#                 },
#                 "low": "acc",
#                 "med": {
#                     "Split Feature": "Doors",
#                     "2": {
#                         "Split Feature": "Lugboot",
#                         "big": "acc",
#                         "small": "unacc"
#                     },
#                     "3": "acc",
#                     "4": "acc",
#                     "5more": "acc"
#                 },
#                 "vhigh": "unacc"
#             },
#             "low": {
#                 "Split Feature": "Maintenance",
#                 "high": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "acc",
#                         "3": "vgood",
#                         "4": "vgood",
#                         "5more": "vgood"
#                     },
#                     "small": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "4": "acc",
#                         "5more": "acc"
#                     }
#                 },
#                 "low": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": "vgood",
#                     "small": "good"
#                 },
#                 "med": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "good",
#                         "3": "vgood",
#                         "4": "vgood",
#                         "5more": "vgood"
#                     },
#                     "small": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "good",
#                         "4": "good",
#                         "5more": "good"
#                     }
#                 },
#                 "vhigh": {
#                     "Split Feature": "Lugboot",
#                     "big": "acc",
#                     "med": "acc",
#                     "small": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc"
#                     }
#                 }
#             },
#             "med": {
#                 "Split Feature": "Maintenance",
#                 "high": {
#                     "Split Feature": "Doors",
#                     "2": {
#                         "Split Feature": "Lugboot",
#                         "med": "acc",
#                         "small": "unacc"
#                     },
#                     "3": "acc",
#                     "4": "acc",
#                     "5more": "acc"
#                 },
#                 "low": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": "vgood",
#                     "small": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "good",
#                         "4": "good",
#                         "5more": "good"
#                     }
#                 },
#                 "med": {
#                     "Split Feature": "Lugboot",
#                     "big": "vgood",
#                     "med": "vgood",
#                     "small": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "5more": "acc"
#                     }
#                 },
#                 "vhigh": {
#                     "Split Feature": "Doors",
#                     "2": {
#                         "Split Feature": "Lugboot",
#                         "med": "acc",
#                         "small": "unacc"
#                     },
#                     "3": "acc",
#                     "4": "acc",
#                     "5more": "acc"
#                 }
#             },
#             "vhigh": {
#                 "Split Feature": "Maintenance",
#                 "high": "unacc",
#                 "low": "acc",
#                 "med": {
#                     "Split Feature": "Doors",
#                     "2": {
#                         "Split Feature": "Lugboot",
#                         "med": "acc",
#                         "small": "unacc"
#                     },
#                     "3": "acc",
#                     "4": "acc",
#                     "5more": "acc"
#                 },
#                 "vhigh": "unacc"
#             }
#         }
#     },
#     "low": "unacc",
#     "med": {
#         "Split Feature": "Persons",
#         "2": "unacc",
#         "4": {
#             "Split Feature": "Buying",
#             "high": {
#                 "Split Feature": "Lugboot",
#                 "big": {
#                     "Split Feature": "Maintenance",
#                     "high": "acc",
#                     "low": "acc",
#                     "med": "acc",
#                     "vhigh": "unacc"
#                 },
#                 "med": {
#                     "Split Feature": "Doors",
#                     "2": "unacc",
#                     "3": "unacc",
#                     "4": {
#                         "Split Feature": "Maintenance",
#                         "high": "acc",
#                         "med": "acc",
#                         "vhigh": "unacc"
#                     },
#                     "5more": "unacc"
#                 },
#                 "small": "unacc"
#             },
#             "low": {
#                 "Split Feature": "Maintenance",
#                 "high": "acc",
#                 "low": {
#                     "Split Feature": "Doors",
#                     "2": "acc",
#                     "3": {
#                         "Split Feature": "Lugboot",
#                         "big": "good",
#                         "med": "acc"
#                     },
#                     "4": "good",
#                     "5more": {
#                         "Split Feature": "Lugboot",
#                         "med": "good",
#                         "small": "acc"
#                     }
#                 },
#                 "med": {
#                     "Split Feature": "Lugboot",
#                     "big": "good",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "acc",
#                         "5more": "good"
#                     },
#                     "small": "acc"
#                 },
#                 "vhigh": {
#                     "Split Feature": "Lugboot",
#                     "big": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "unacc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "small": "unacc"
#                 }
#             },
#             "med": {
#                 "Split Feature": "Maintenance",
#                 "high": {
#                     "Split Feature": "Lugboot",
#                     "big": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "unacc",
#                         "5more": "acc"
#                     },
#                     "small": "unacc"
#                 },
#                 "low": {
#                     "Split Feature": "Lugboot",
#                     "big": "good",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "3": "acc",
#                         "5more": "good"
#                     },
#                     "small": "acc"
#                 },
#                 "med": "acc",
#                 "vhigh": {
#                     "Split Feature": "Lugboot",
#                     "big": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "unacc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "small": "unacc"
#                 }
#             },
#             "vhigh": {
#                 "Split Feature": "Maintenance",
#                 "high": "unacc",
#                 "low": {
#                     "Split Feature": "Lugboot",
#                     "big": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "small": "unacc"
#                 },
#                 "med": {
#                     "Split Feature": "Lugboot",
#                     "big": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "unacc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "small": "unacc"
#                 },
#                 "vhigh": "unacc"
#             }
#         },
#         "more": {
#             "Split Feature": "Lugboot",
#             "big": {
#                 "Split Feature": "Maintenance",
#                 "high": {
#                     "Split Feature": "Buying",
#                     "high": "acc",
#                     "low": "acc",
#                     "med": "acc",
#                     "vhigh": "unacc"
#                 },
#                 "low": {
#                     "Split Feature": "Buying",
#                     "high": "acc",
#                     "low": "good",
#                     "med": "good",
#                     "vhigh": "acc"
#                 },
#                 "med": {
#                     "Split Feature": "Buying",
#                     "high": "acc",
#                     "low": "good",
#                     "med": "acc",
#                     "vhigh": "acc"
#                 },
#                 "vhigh": {
#                     "Split Feature": "Buying",
#                     "high": "unacc",
#                     "low": "acc",
#                     "med": "acc",
#                     "vhigh": "unacc"
#                 }
#             },
#             "med": {
#                 "Split Feature": "Buying",
#                 "high": {
#                     "Split Feature": "Maintenance",
#                     "high": "acc",
#                     "low": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "vhigh": "unacc"
#                 },
#                 "low": {
#                     "Split Feature": "Maintenance",
#                     "high": "acc",
#                     "low": {
#                         "Split Feature": "Doors",
#                         "2": "acc",
#                         "3": "good",
#                         "5more": "good"
#                     },
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "acc",
#                         "3": "good",
#                         "4": "good",
#                         "5more": "good"
#                     },
#                     "vhigh": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc",
#                         "4": "acc",
#                         "5more": "acc"
#                     }
#                 },
#                 "med": {
#                     "Split Feature": "Maintenance",
#                     "high": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc",
#                         "4": "acc"
#                     },
#                     "low": {
#                         "Split Feature": "Doors",
#                         "2": "acc",
#                         "3": "good",
#                         "4": "good",
#                         "5more": "good"
#                     },
#                     "med": "acc",
#                     "vhigh": "acc"
#                 },
#                 "vhigh": {
#                     "Split Feature": "Maintenance",
#                     "high": "unacc",
#                     "low": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc",
#                         "4": "acc"
#                     },
#                     "vhigh": "unacc"
#                 }
#             },
#             "small": {
#                 "Split Feature": "Buying",
#                 "high": "unacc",
#                 "low": {
#                     "Split Feature": "Maintenance",
#                     "high": "acc",
#                     "low": "acc",
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "vhigh": "unacc"
#                 },
#                 "med": {
#                     "Split Feature": "Maintenance",
#                     "high": "unacc",
#                     "low": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "3": "acc",
#                         "4": "acc",
#                         "5more": "acc"
#                     },
#                     "med": {
#                         "Split Feature": "Doors",
#                         "2": "unacc",
#                         "5more": "acc"
#                     },
#                     "vhigh": "unacc"
#                 },
#                 "vhigh": "unacc"
#             }
#         }
#     }
# }

# %% [markdown]
# ***DECISION RULES***

# %%
print_decisionRules(rules)
# Out:
# (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = vhigh ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = vhigh) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = vhigh ∧ Lugboot = small ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = high ∧ Doors = 2) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = vhigh ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = low ∧ Doors = 2) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = vhigh ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = high ∧ Lugboot = med ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = high) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = med ∧ Doors = 2 ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = vhigh ∧ Doors = 2 ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = small ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = vhigh ∧ Buying = vhigh) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = high ∧ Doors = 2 ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = high ∧ Lugboot = med ∧ Doors = 4 ∧ Maintenance = vhigh) ∨ (Safety = low) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = vhigh) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = high) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = vhigh ∧ Maintenance = med ∧ Doors = 2) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = vhigh) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = high ∧ Maintenance = med ∧ Doors = 2) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = high) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = vhigh ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = high ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = vhigh ∧ Maintenance = high) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = vhigh ∧ Maintenance = vhigh) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = high ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = small ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = low ∧ Maintenance = vhigh) ∨ (Safety = med ∧ Persons = 2) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = high ∧ Maintenance = vhigh) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = vhigh ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = vhigh) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = high ∧ Doors = 2 ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = high) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = low ∧ Maintenance = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = vhigh ∧ Buying = high) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = high ∧ Buying = vhigh) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = low ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = high ∧ Maintenance = vhigh) ∨ (Safety = high ∧ Persons = more ∧ Buying = vhigh ∧ Maintenance = vhigh) ∨ (Safety = high ∧ Persons = 2) ∨ (Safe ...
#
# (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = high ∧ Buying = high) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = vhigh ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = high ∧ Buying = med) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = high ∧ Doors = 2 ∧ Lugboot = med) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Doors = 5more ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = high ∧ Doors = 4) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = med ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = vhigh ∧ Maintenance = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = high ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = med ∧ Doors = 4) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = vhigh ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = vhigh ∧ Maintenance = med ∧ Doors = 3) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = high ∧ Doors = 3) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = med ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = vhigh ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = vhigh ∧ Maintenance = med ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = high ∧ Maintenance = high) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = vhigh ∧ Buying = med) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = med ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = high) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = med ∧ Lugboot = small ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = high) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = high ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = high ∧ Maintenance = med ∧ Doors = 2 ∧ Lugboot = big) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Doors = 2) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = low ∧ Doors = 4) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = med) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = med ∧ Buying = high) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = med) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = low ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = med ∧ Buying = med) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = low ∧ Buying = high) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = high ∧ Doors = 3) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = high ∧ Lugboot = med ∧ Doors = 4 ∧ Maintenance = high) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = small ∧ Doors = 4) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = vhigh ∧ Maintenance = low ∧ Lugboot = big) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = small ∧ Buying = med ∧ Maintenance = low ∧ Doors = 3) ∨ (Safety ...
#
# (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = med) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 3) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 3) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = med ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = med) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = med ∧ Lugboot = med) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = med ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = high ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 5more) => vgood
# (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = med ∧ Buying = low) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = low ∧ Doors = 3) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = low ∧ Doors = 4) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = small ∧ Doors = 4) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = low ∧ Buying = low) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 3) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = small ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = low ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = small ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = big ∧ Maintenance = low ∧ Buying = med) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Doors = 3 ∧ Lugboot = big) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = small) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = med ∧ Maintenance = low ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = med ∧ Doors = 3) ∨ (Safety = high ∧ Persons = more ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = small ∧ Doors = 3) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = med ∧ Doors = 4) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = low ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = med ∧ Doors = 5more) ∨ (Safety = med ∧ Persons = more ∧ Lugboot = med ∧ Buying = low ∧ Maintenance = med ∧ Doors = 5more) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = med ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Lugboot = small) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = small ∧ Doors = 4) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Doors = 4) ∨ (Safety = med ∧ Persons = 4 ∧ Buying = low ∧ Maintenance = low ∧ Doors = 5more ∧ Lugboot = med) ∨ (Safety = high ∧ Persons = 4 ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = med ∧ Doors = 2) ∨ (Safety = high ∧ Persons = more ∧ Buying = med ∧ Maintenance = low ∧ Lugboot = small ∧ Doors = 5more) => good

# %% [markdown]
# ***TRAINING SET ACCURACY***

# %%
from sklearn.metrics import accuracy_score

y_train_pred = []
for instance in X_train.iterrows():
    y = predict(instance[1],decisiontree)
    y_train_pred.append(y)
print("Training set Accuracy score =",accuracy_score(X_train['Class'],y_train_pred)*100)
# Out:
# Training set Accuracy score = 100.0

# %% [markdown]
# ***TEST SET ACCURACY***

# %%
y_pred = []
i = 1
for instance in X_test.iterrows():
    y = predict(instance[1],decisiontree)
    y_pred.append(y)
print("Testing set Accuracy score =",accuracy_score(X_test['Class'],y_pred)*100)
# Out:
# Testing set Accuracy score = 89.88439306358381
